# %%
import pins

board = pins.board_databricks("/Volumes/sol_eng_demo_nickp/end-to-end/r-models")

board.pin_list()
# Out:
# ['large_differences', 'lending-model-linear']

# %%
large_difference = board.pin_read("large_differences")

large_difference
# Out:
#         _pred  interest_rate  ... paid_late_fees       diff
# 0    8.533609          26.77  ...              0  18.236391
# 1   10.754186          25.82  ...              0  15.065814
# 2   17.084278          30.17  ...              0  13.085722
# 3    9.158120          21.85  ...              0  12.691880
# 4   13.504009          30.17  ...              0  16.665991
# ..        ...            ...  ...            ...        ...
# 81  -3.190129          12.62  ...             15  15.810129
# 82  10.811037          23.88  ...              0  13.068963
# 83 -15.998465           5.31  ...              0  21.308465
# 84  10.525692          24.84  ...              0  14.314308
# 85  13.346295          29.69  ...              0  16.343705
#
# [86 rows x 57 columns]

# %%
import pandas as pd

large_difference.sort_values('diff')
# Out:
#         _pred  interest_rate  ... paid_late_fees       diff
# 53  13.409875          25.81  ...              0  12.400125
# 79  17.119541          29.69  ...              0  12.570459
# 61  11.284204          23.87  ...              0  12.585796
# 45  13.154522          25.81  ...              0  12.655478
# 16  11.213350          23.88  ...              0  12.666650
# ..        ...            ...  ...            ...        ...
# 83 -15.998465           5.31  ...              0  21.308465
# 48   7.944094          30.65  ...              0  22.705906
# 5   -8.866572          17.47  ...              0  26.336572
# 32 -23.215749           7.34  ...              0  30.555749
# 78 -35.233841           9.44  ...              0  44.673841
#
# [86 rows x 57 columns]

# %%
# Continue analysis ...

# %%
pip install git+https://github.com/rstudio/pins-python.git@databricks
